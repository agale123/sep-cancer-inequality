# %%
import pandas as pd

# %%
# Create a function that allows you to read a file, rename columns, and add it to the dataframe
def add_file(old_df, file, cols):
    df_new = pd.read_csv("../../data/raw/" + file, header=1)
    df_new = df_new.rename(columns=cols)
    df_new = df_new[cols.values()]
    return old_df.join(df_new.set_index("county_fips"), on="county_fips")

# %%
# Start with the incidence rate of all cancers for both sexes
file = "Incidence_US_by_County_All_Races_All_Cancer_Sites_(Both_Sexes)_2013_-_2017.csv"
df = pd.read_csv("../../data/raw/" + file, header=1)
df = df.rename(columns = {"County FIPS": "county_fips", "Age-Adjusted Rate per 100,000": "cancer_incidence_rate"})
df = df[["county_fips", "cancer_incidence_rate"]]
df
# Out:
#       county_fips  cancer_incidence_rate
# 0           12125                 1143.5
# 1           31113                  739.4
# 2           40055                  710.4
# 3           21197                  648.2
# 4           31163                  629.5
# ...           ...                    ...
# 1995        31107                  431.4
# 1996        48497                  431.4
# 1997        51113                  431.4
# 1998        46019                  431.4
# 1999         4015                  431.2
#
# [2000 rows x 2 columns]

# %%
# Mortality
df = add_file(
    df,
    "Mortality_US_by_County_All_Races_All_Malignant_Cancers_(Both_Sexes)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Age-Adjusted Rate per 100,000": "cancer_mortality_rate"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
# [2000 rows x 3 columns]

# %%
# Household income
df = add_file(
    df,
    "Demographics_US_by_County_Income_Median_Household_Income_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Dollars": "median_household_income"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income
# 0                         NaN
# 1                     51607.0
# 2                         NaN
# 3                         NaN
# 4                     51172.0
# ...                       ...
# 1995                  49752.0
# 1996                  61709.0
# 1997                  54197.0
# 1998                      NaN
# 1999                      NaN
#
# [2000 rows x 4 columns]

# %%
# Language isolation
df = add_file(
    df,
    "Demographics_US_by_County_Non-English_Language_Language_Isolation_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "language_isolation_percent"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income  language_isolation_percent
# 0                         NaN                         NaN
# 1                     51607.0                         1.8
# 2                         NaN                         0.7
# 3                         NaN                         NaN
# 4                     51172.0                         NaN
# ...                       ...                         ...
# 1995                  49752.0                         0.8
# 1996                  61709.0                         3.3
# 1997                  54197.0                         0.5
# 1998                      NaN                         NaN
# 1999                      NaN                         1.6
#
# [2000 rows x 5 columns]

# %%
# Age demographics
df = add_file(
    df,
    "Demographics_US_by_County_Population_Age_65_and_Over_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "over_65_percent"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income  language_isolation_percent  over_65_percent
# 0                         NaN                         NaN             34.6
# 1                     51607.0                         1.8              NaN
# 2                         NaN                         0.7             33.5
# 3                         NaN                         NaN             33.5
# 4                     51172.0                         NaN             34.0
# ...                       ...                         ...              ...
# 1995                  49752.0                         0.8              NaN
# 1996                  61709.0                         3.3             33.6
# 1997                  54197.0                         0.5             33.1
# 1998                      NaN                         NaN              NaN
# 1999                      NaN                         1.6              NaN
#
# [2000 rows x 6 columns]

# %%
# Families below the poverty line
df = add_file(
    df,
    "Demographics_US_by_County_Poverty_Families_Below_Poverty_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "below_poverty_percent"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income  language_isolation_percent  over_65_percent  \
# 0                         NaN                         NaN             34.6
# 1                     51607.0                         1.8              NaN
# 2                         NaN                         0.7             33.5
# 3                         NaN                         NaN             33.5
# 4                     51172.0                         NaN             34.0
# ...                       ...                         ...              ...
# 1995                  49752.0                         0.8              NaN
# 1996                  61709.0                         3.3             33.6
# 1997                  54197.0                         0.5             33.1
# 1998                      NaN                         NaN              NaN
# 1999                      NaN                         1.6              NaN
#
#       below_poverty_percent
# 0                      17.6
# 1                       NaN
# 2                      14.7
# 3                      16.4
# 4                       9.1
# ...                     ...
# 1995                    NaN
# 1996                    9.2
# 1997                    NaN
# 1998                    NaN
# 1999                   11.6
#
# [2000 rows x 7 columns]

# %%
# Uninsured rate
df = add_file(
    df,
    "Demographics_US_by_County_Uninsured_Ages__65_at_or_below_138%_of_Poverty_(Both_Sexes_-_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "uninsured_percent"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income  language_isolation_percent  over_65_percent  \
# 0                         NaN                         NaN             34.6
# 1                     51607.0                         1.8              NaN
# 2                         NaN                         0.7             33.5
# 3                         NaN                         NaN             33.5
# 4                     51172.0                         NaN             34.0
# ...                       ...                         ...              ...
# 1995                  49752.0                         0.8              NaN
# 1996                  61709.0                         3.3             33.6
# 1997                  54197.0                         0.5             33.1
# 1998                      NaN                         NaN              NaN
# 1999                      NaN                         1.6              NaN
#
#       below_poverty_percent  uninsured_percent
# 0                      17.6               18.6
# 1                       NaN               16.9
# 2                      14.7               19.0
# 3                      16.4                NaN
# 4                       9.1               19.8
# ...                     ...                ...
# 1995                    NaN               18.0
# 1996                    9.2               36.1
# 1997                    NaN               20.9
# 1998                    NaN               21.9
# 1999                   11.6               15.2
#
# [2000 rows x 8 columns]

# %%
# Ultraviolet exposure
df = add_file(
    df,
    "Screening_and_Risk_Factors_US_by_County_(UV_Only)_UV_Exposure_Data_Ultraviolet_Exposure.csv",
    {"County FIPS": "county_fips", "Watt-Hours Per Square Meter": "uv_exposure"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income  language_isolation_percent  over_65_percent  \
# 0                         NaN                         NaN             34.6
# 1                     51607.0                         1.8              NaN
# 2                         NaN                         0.7             33.5
# 3                         NaN                         NaN             33.5
# 4                     51172.0                         NaN             34.0
# ...                       ...                         ...              ...
# 1995                  49752.0                         0.8              NaN
# 1996                  61709.0                         3.3             33.6
# 1997                  54197.0                         0.5             33.1
# 1998                      NaN                         NaN              NaN
# 1999                      NaN                         1.6              NaN
#
#       below_poverty_percent  uninsured_percent  uv_exposure
# 0                      17.6               18.6       4668.0
# 1                       NaN               16.9       4378.0
# 2                      14.7               19.0       4937.0
# 3                      16.4                NaN          NaN
# 4                       9.1               19.8       4401.0
# ...                     ...                ...          ...
# 1995                    NaN               18.0       4206.0
# 1996                    9.2               36.1       4903.0
# 1997                    NaN               20.9       4119.0
# 1998                    NaN               21.9       4201.0
# 1999                   11.6               15.2       5425.0
#
# [2000 rows x 9 columns]

# %%
# Racial demographic data
df = add_file(
    df,
    "Demographics_US_by_County_Population_Asian_Pacific_Islander_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "asian_pacific_islander_percent"},
)
df = add_file(
    df,
    "Demographics_US_by_County_Population_Black_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "black_percent"},
)
df = add_file(
    df,
    "Demographics_US_by_County_Population_Hispanic_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "hispanic_percent"},
)
df = add_file(
    df,
    "Demographics_US_by_County_Population_White_(Both_Sexes_-_2014_to_2018)_2014_-_2018.csv",
    {"County FIPS": "county_fips", "Percent": "white_percent"},
)
df
# Out:
#       county_fips  cancer_incidence_rate  cancer_mortality_rate  \
# 0           12125                 1143.5                 454.48
# 1           31113                  739.4                    NaN
# 2           40055                  710.4                 209.41
# 3           21197                  648.2                 246.56
# 4           31163                  629.5                    NaN
# ...           ...                    ...                    ...
# 1995        31107                  431.4                    NaN
# 1996        48497                  431.4                 181.40
# 1997        51113                  431.4                 181.05
# 1998        46019                  431.4                 178.03
# 1999         4015                  431.2                 183.30
#
#       median_household_income  language_isolation_percent  over_65_percent  \
# 0                         NaN                         NaN             34.6
# 1                     51607.0                         1.8              NaN
# 2                         NaN                         0.7             33.5
# 3                         NaN                         NaN             33.5
# 4                     51172.0                         NaN             34.0
# ...                       ...                         ...              ...
# 1995                  49752.0                         0.8              NaN
# 1996                  61709.0                         3.3             33.6
# 1997                  54197.0                         0.5             33.1
# 1998                      NaN                         NaN              NaN
# 1999                      NaN                         1.6              NaN
#
#       below_poverty_percent  uninsured_percent  uv_exposure  \
# 0                      17.6               18.6       4668.0
# 1                       NaN               16.9       4378.0
# 2                      14.7               19.0       4937.0
# 3                      16.4                NaN          NaN
# 4                       9.1               19.8       4401.0
# ...                     ...                ...          ...
# 1995                    NaN               18.0       4206.0
# 1996                    9.2               36.1       4903.0
# 1997                    NaN               20.9       4119.0
# 1998                    NaN               21.9       4201.0
# 1999                   11.6               15.2       5425.0
#
#       asian_pacific_islander_percent  black_percent  hispanic_percent  \
# 0                                0.6           21.9               5.5
# 1                                NaN            NaN               2.9
# 2                                NaN            8.3              11.3
# 3                                0.6            NaN               NaN
# 4                                0.7            NaN               NaN
# ...                              ...            ...               ...
# 1995                             NaN            NaN               NaN
# 1996                             0.6            1.3              19.0
# 1997                             0.8            6.9               NaN
# 1998                             NaN            NaN               3.5
# 1999                             1.5            NaN              16.2
#
#       white_percent
# 0               NaN
# 1              98.6
# 2               NaN
# 3              96.8
# 4              98.0
# ...             ...
# 1995           86.8
# 1996           93.3
# 1997           85.8
# 1998           94.3
# 1999           90.5
#
# [2000 rows x 13 columns]

# %%
df.to_csv("../../data/processed/nci.csv", index=False)
