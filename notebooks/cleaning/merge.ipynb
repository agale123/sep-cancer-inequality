# %%
import pandas as pd

# %% [markdown]
# # County data
#
# Merge all of the county-level dataframes into a single file for analysis.

# %%
# Start with the NCI dataset
df = pd.read_csv("../../data/processed/nci.csv")
df
# Out:
#        fips  cancer_incidence_rate_per_100000  \
# 0     12125                            1143.5
# 1     31113                             739.4
# 2     40055                             710.4
# 3     21197                             648.2
# 4     31163                             629.5
# ...     ...                               ...
# 1995  31107                             431.4
# 1996  48497                             431.4
# 1997  51113                             431.4
# 1998  46019                             431.4
# 1999   4015                             431.2
#
#       cancer_mortality_rate_per_100000  \
# 0                               454.48
# 1                                  NaN
# 2                               209.41
# 3                               246.56
# 4                                  NaN
# ...                                ...
# 1995                               NaN
# 1996                            181.40
# 1997                            181.05
# 1998                            178.03
# 1999                            183.30
#
#       breast_cancer_incidence_rate_per_100000  \
# 0                                       190.2
# 1                                         NaN
# 2                                       234.0
# 3                                       128.8
# 4                                       157.1
# ...                                       ...
# 1995                                    160.0
# 1996                                      NaN
# 1997                                      NaN
# 1998                                      NaN
# 1999                                    112.7
#
#       breast_cancer_mortality_rate_per_100000  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1995                                      NaN
# 1996                                    28.48
# 1997                                      NaN
# 1998                                      NaN
# 1999                                    25.81
#
#       colorectal_cancer_incidence_rate_per_100000  \
# 0                                           121.7
# 1                                             NaN
# 2                                            60.4
# 3                                            73.2
# 4                                             NaN
# ...                                           ...
# 1995                                          NaN
# 1996                                         43.7
# 1997                                         45.8
# 1998                                         52.7
# 1999                                         37.5
#
#       colorectal_cancer_mortality_rate_per_100000  \
# 0                                           45.14
# 1                                             NaN
# 2                                             NaN
# 3                                           26.48
# 4                                             NaN
# ...                                           ...
# 1995                                          NaN
# 1996                                        16.51
# 1997                                        18.40
# 1998                                          NaN
# 1999                                        17.21
#
#       lung_cancer_incidence_rate_per_100000  \
# 0                                     196.3
# 1                                       NaN
# 2                                      95.4
# 3                                     132.5
# 4                                       NaN
# ...                                     ...
# 1995                                    NaN
# 1996                                   72.1
# 1997                                   75.6
# 1998                                   64.0
# 1999                                   73.8
#
#       lung_cancer_mortality_rate_per_100000  \
# 0                                    147.94
# 1                                       NaN
# 2                                     61.15
# 3                                     90.67
# 4                                       NaN
# ...                                     ...
# 1995                                    NaN
# 1996                                  55.09
# 1997                                  42.07
# 1998                                  53.59
# 1999                                  51.70
#
#       prostate_cancer_incidence_rate_per_100000  ...  median_household_income  \
# 0                                         230.6  ...                      NaN
# 1                                           NaN  ...                  51607.0
# 2                                         140.3  ...                      NaN
# 3                                           NaN  ...                      NaN
# 4                                         161.8  ...                  51172.0
# ...                                         ...  ...                      ...
# 1995                                      110.7  ...                  49752.0
# 1996                                        NaN  ...                  61709.0
# 1997                                        NaN  ...                  54197.0
# 1998                                        NaN  ...                      NaN
# 1999                                        NaN  ...                      NaN
#
#       language_isolation_percent  over_65_percent  below_poverty_percent  \
# 0                            NaN             34.6                   17.6
# 1                            1.8              NaN                    NaN
# 2                            0.7             33.5                   14.7
# 3                            NaN             33.5                   16.4
# 4                            NaN             34.0                    9.1
# ...                          ...              ...                    ...
# 1995                         0.8              NaN                    NaN
# 1996                         3.3             33.6                    9.2
# 1997                         0.5             33.1                    NaN
# 1998                         NaN              NaN                    NaN
# 1999                         1.6              NaN                   11.6
#
#       uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 0                  18.6       4668.0                             0.6
# 1                  16.9       4378.0                             NaN
# 2                  19.0       4937.0                             NaN
# 3                   NaN          NaN                             0.6
# 4                  19.8       4401.0                             0.7
# ...                 ...          ...                             ...
# 1995               18.0       4206.0                             NaN
# 1996               36.1       4903.0                             0.6
# 1997               20.9       4119.0                             0.8
# 1998               21.9       4201.0                             NaN
# 1999               15.2       5425.0                             1.5
#
#       black_percent  hispanic_percent  white_percent
# 0              21.9               5.5            NaN
# 1               NaN               2.9           98.6
# 2               8.3              11.3            NaN
# 3               NaN               NaN           96.8
# 4               NaN               NaN           98.0
# ...             ...               ...            ...
# 1995            NaN               NaN           86.8
# 1996            1.3              19.0           93.3
# 1997            6.9               NaN           85.8
# 1998            NaN               3.5           94.3
# 1999            NaN              16.2           90.5
#
# [2000 rows x 21 columns]

# %%
files = [
    "food_access.csv",
    "language_barriers.csv",
    "social_vulnerability_index.csv",
    "walkability.csv"
]

# %%
for f in files:
    df2 = pd.read_csv("../../data/processed/" + f)
    df = df.set_index("fips").join(df2.set_index("fips"), how="outer").reset_index()
df
# Out:
#        fips  cancer_incidence_rate_per_100000  \
# 0      1001                             490.1
# 1      1003                             452.4
# 2      1005                               NaN
# 3      1007                             467.3
# 4      1009                             432.0
# ...     ...                               ...
# 3232  72151                               NaN
# 3233  72153                               NaN
# 3234  78010                               NaN
# 3235  78020                               NaN
# 3236  78030                               NaN
#
#       cancer_mortality_rate_per_100000  \
# 0                               163.48
# 1                               165.47
# 2                                  NaN
# 3                               187.60
# 4                               176.72
# ...                                ...
# 3232                               NaN
# 3233                               NaN
# 3234                               NaN
# 3235                               NaN
# 3236                               NaN
#
#       breast_cancer_incidence_rate_per_100000  \
# 0                                       129.9
# 1                                       128.1
# 2                                         NaN
# 3                                       140.7
# 4                                       130.0
# ...                                       ...
# 3232                                      NaN
# 3233                                      NaN
# 3234                                      NaN
# 3235                                      NaN
# 3236                                      NaN
#
#       breast_cancer_mortality_rate_per_100000  \
# 0                                       21.59
# 1                                       22.20
# 2                                         NaN
# 3                                       22.05
# 4                                       20.36
# ...                                       ...
# 3232                                      NaN
# 3233                                      NaN
# 3234                                      NaN
# 3235                                      NaN
# 3236                                      NaN
#
#       colorectal_cancer_incidence_rate_per_100000  \
# 0                                            49.5
# 1                                            40.4
# 2                                             NaN
# 3                                            47.0
# 4                                            36.7
# ...                                           ...
# 3232                                          NaN
# 3233                                          NaN
# 3234                                          NaN
# 3235                                          NaN
# 3236                                          NaN
#
#       colorectal_cancer_mortality_rate_per_100000  \
# 0                                           15.19
# 1                                           13.93
# 2                                             NaN
# 3                                           14.30
# 4                                           14.17
# ...                                           ...
# 3232                                          NaN
# 3233                                          NaN
# 3234                                          NaN
# 3235                                          NaN
# 3236                                          NaN
#
#       lung_cancer_incidence_rate_per_100000  \
# 0                                      67.8
# 1                                      70.0
# 2                                       NaN
# 3                                      78.3
# 4                                      70.3
# ...                                     ...
# 3232                                    NaN
# 3233                                    NaN
# 3234                                    NaN
# 3235                                    NaN
# 3236                                    NaN
#
#       lung_cancer_mortality_rate_per_100000  \
# 0                                     48.43
# 1                                     47.25
# 2                                       NaN
# 3                                     54.26
# 4                                     53.94
# ...                                     ...
# 3232                                    NaN
# 3233                                    NaN
# 3234                                    NaN
# 3235                                    NaN
# 3236                                    NaN
#
#       prostate_cancer_incidence_rate_per_100000  ...  population_in_poverty  \
# 0                                         133.2  ...                12611.0
# 1                                          88.4  ...                36413.0
# 2                                           NaN  ...                 8965.0
# 3                                         112.7  ...                 5730.0
# 4                                          96.9  ...                13624.0
# ...                                         ...  ...                    ...
# 3232                                        NaN  ...                    NaN
# 3233                                        NaN  ...                    NaN
# 3234                                        NaN  ...                    NaN
# 3235                                        NaN  ...                    NaN
# 3236                                        NaN  ...                    NaN
#
#       population_over_16_unemployed  \
# 0                             736.0
# 1                            4027.0
# 2                             649.0
# 3                             667.0
# 4                            1253.0
# ...                             ...
# 3232                            NaN
# 3233                            NaN
# 3234                            NaN
# 3235                            NaN
# 3236                            NaN
#
#       population_over_25_no_high_school_diploma  population_over_65  \
# 0                                        4273.0              8490.0
# 1                                       14823.0             44716.0
# 2                                        4497.0              4777.0
# 3                                        3056.0              3676.0
# 4                                        6838.0             10382.0
# ...                                         ...                 ...
# 3232                                        NaN                 NaN
# 3233                                        NaN                 NaN
# 3234                                        NaN                 NaN
# 3235                                        NaN                 NaN
# 3236                                        NaN                 NaN
#
#       population_under_17  population_uninsured  population_with_disability  \
# 0                 13143.0                4345.0                      9658.0
# 1                 46993.0               20501.0                     30615.0
# 2                  5222.0                2362.0                      4159.0
# 3                  4584.0                1878.0                      3748.0
# 4                 13372.0                5746.0                      8564.0
# ...                   ...                   ...                         ...
# 3232                  NaN                   NaN                         NaN
# 3233                  NaN                   NaN                         NaN
# 3234                  NaN                   NaN                         NaN
# 3235                  NaN                   NaN                         NaN
# 3236                  NaN                   NaN                         NaN
#
#       single_parent_households  population_minority  walkability_index
# 0                       1608.0              14479.0           5.483179
# 1                       3317.0              37334.0           6.812530
# 2                       1029.0              13694.0           5.156175
# 3                        790.0               5724.0           5.241296
# 4                       1313.0               7690.0           4.674447
# ...                        ...                  ...                ...
# 3232                       NaN                  NaN           3.385946
# 3233                       NaN                  NaN           4.541645
# 3234                       NaN                  NaN           4.280686
# 3235                       NaN                  NaN           4.179696
# 3236                       NaN                  NaN           4.667674
#
# [3237 rows x 37 columns]

# %%
# Write out the merged data
df.to_csv("../../data/final/county_data.csv", index=False)

# %% [markdown]
# # Location data
#
# Copy over all latitude/longitude and redline data files to the final folder.

# %%
files = [
    "oil_accidents.csv",
    "redlining.csv"
]

# %%
for f in files:
    df = pd.read_csv("../../data/processed/" + f)
    df.to_csv("../../data/final/" + f, index=False)
# Out:
#        latitude   longitude  oil_barrels_spilled  spill_count
# 0     18.448010  -66.074760                66.00            1
# 1     21.304380 -158.093700                14.00            1
# 2     21.316680 -158.099930                 3.00            1
# 3     21.317740 -157.890550              1300.00            1
# 4     23.336784  -94.958220              1413.00            1
# ...         ...         ...                  ...          ...
# 2563  70.107620 -147.386330                 0.01            1
# 2564  70.151205 -147.096536                 0.28            1
# 2565  70.256660 -148.620300               308.00            1
# 2566  70.257147 -148.621973                 4.31            1
# 2567  70.261265 -148.611844                 6.00            1
#
# [2568 rows x 4 columns]

# %%
# Write out the merged data
