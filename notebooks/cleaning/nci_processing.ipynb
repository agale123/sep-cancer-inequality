# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reconciling state and county data
#
# The NCI data is available at both the state and county level but many counties are missing data due to less detailed reporting or low data counts. The goal of this script is to combine the local and state values to fill in estimates of the missing county-level values.

# %% [markdown]
# ## Read initial data
# Take in the procesed state and county data and population data from the Social Vulnerability Index

# %%
# Already processed state-level NCI data
state = pd.read_csv("../../data/processed/nci_state.csv")
state.head()
# Out:
#    fips  cancer_incidence_rate_per_100000  cancer_mortality_rate_per_100000  \
# 0     1                             451.5                            173.42
# 1     2                             417.2                            152.62
# 2     4                             386.7                            137.88
# 3     5                             472.8                            177.63
# 4     6                             404.6                            140.30
#
#    breast_cancer_incidence_rate_per_100000  \
# 0                                    121.6
# 1                                    120.8
# 2                                    114.4
# 3                                    118.2
# 4                                    121.5
#
#    breast_cancer_mortality_rate_per_100000  \
# 0                                    21.54
# 1                                    18.80
# 2                                    18.47
# 3                                    20.33
# 4                                    19.35
#
#    cervical_cancer_incidence_rate_per_100000  \
# 0                                        9.4
# 1                                        7.1
# 2                                        6.5
# 3                                        9.5
# 4                                        7.2
#
#    cervical_cancer_mortality_rate_per_100000  \
# 0                                       3.46
# 1                                       1.65
# 2                                       2.10
# 3                                       3.43
# 4                                       2.24
#
#    colorectal_cancer_incidence_rate_per_100000  \
# 0                                         43.6
# 1                                         42.6
# 2                                         32.6
# 3                                         44.1
# 4                                         35.1
#
#    colorectal_cancer_mortality_rate_per_100000  \
# 0                                        15.46
# 1                                        15.05
# 2                                        12.62
# 3                                        15.59
# 4                                        12.50
#
#    lung_cancer_incidence_rate_per_100000  ...  \
# 0                                   64.9  ...
# 1                                   55.8  ...
# 2                                   46.8  ...
# 3                                   77.2  ...
# 4                                   41.5  ...
#
#    melanoma_cancer_mortality_rate_per_100000  \
# 0                                       2.38
# 1                                       2.19
# 2                                       2.48
# 3                                       2.12
# 4                                       2.06
#
#    leukemia_cancer_incidence_rate_per_100000  \
# 0                                       12.3
# 1                                       11.8
# 2                                       11.0
# 3                                       14.5
# 4                                       12.5
#
#    leukemia_cancer_mortality_rate_per_100000  \
# 0                                       6.40
# 1                                       5.55
# 2                                       5.85
# 3                                       6.79
# 4                                       5.86
#
#    non_hodgkin_lymphoma_cancer_incidence_rate_per_100000  \
# 0                                               16.2
# 1                                               17.1
# 2                                               15.5
# 3                                               18.2
# 4                                               18.4
#
#    non_hodgkin_lymphoma_cancer_mortality_rate_per_100000  \
# 0                                               5.02
# 1                                               5.50
# 2                                               4.67
# 3                                               5.30
# 4                                               5.17
#
#    hodgkins_lymphoma_cancer_mortality_rate_per_100000  \
# 0                                               0.31
# 1                                                NaN
# 2                                               0.28
# 3                                               0.30
# 4                                               0.31
#
#    hodgkins_lymphoma_cancer_incidence_rate_per_100000  \
# 0                                               2.42
# 1                                               2.13
# 2                                               2.00
# 3                                               2.62
# 4                                               2.18
#
#    colorectal_screening_percent  smoking_percent  hpv_vaccine_percent
# 0                         76.07            43.94                 34.9
# 1                         68.36            43.22                 32.3
# 2                         75.32            40.35                 39.9
# 3                         73.39            47.06                 26.8
# 4                         75.60            33.45                 38.8
#
# [5 rows x 24 columns]

# %%
# Already processed county-level NCI data
county = pd.read_csv("../../data/processed/nci_county.csv")
county
# Out:
#        fips  cancer_incidence_rate_per_100000  \
# 0      1001                             490.1
# 1      1003                             452.4
# 2      1005                               NaN
# 3      1007                             467.3
# 4      1009                             432.0
# ...     ...                               ...
# 3137  56037                               NaN
# 3138  56039                               NaN
# 3139  56041                               NaN
# 3140  56043                               NaN
# 3141  56045                               NaN
#
#       cancer_mortality_rate_per_100000  \
# 0                               163.48
# 1                               165.47
# 2                               182.94
# 3                               187.60
# 4                               176.72
# ...                                ...
# 3137                               NaN
# 3138                               NaN
# 3139                               NaN
# 3140                               NaN
# 3141                               NaN
#
#       breast_cancer_incidence_rate_per_100000  \
# 0                                       129.9
# 1                                       128.1
# 2                                         NaN
# 3                                       140.7
# 4                                       130.0
# ...                                       ...
# 3137                                      NaN
# 3138                                    141.0
# 3139                                    139.5
# 3140                                    130.2
# 3141                                    129.2
#
#       breast_cancer_mortality_rate_per_100000  \
# 0                                       21.59
# 1                                       22.20
# 2                                         NaN
# 3                                       22.05
# 4                                       20.36
# ...                                       ...
# 3137                                    21.63
# 3138                                      NaN
# 3139                                    31.52
# 3140                                      NaN
# 3141                                      NaN
#
#       colorectal_cancer_incidence_rate_per_100000  \
# 0                                            49.5
# 1                                            40.4
# 2                                            44.1
# 3                                            47.0
# 4                                            36.7
# ...                                           ...
# 3137                                          NaN
# 3138                                          NaN
# 3139                                          NaN
# 3140                                         44.7
# 3141                                          NaN
#
#       colorectal_cancer_mortality_rate_per_100000  \
# 0                                           15.19
# 1                                           13.93
# 2                                           15.42
# 3                                           14.30
# 4                                           14.17
# ...                                           ...
# 3137                                        14.20
# 3138                                          NaN
# 3139                                          NaN
# 3140                                          NaN
# 3141                                          NaN
#
#       lung_cancer_incidence_rate_per_100000  \
# 0                                      67.8
# 1                                      70.0
# 2                                      63.1
# 3                                      78.3
# 4                                      70.3
# ...                                     ...
# 3137                                    NaN
# 3138                                    NaN
# 3139                                    NaN
# 3140                                    NaN
# 3141                                    NaN
#
#       lung_cancer_mortality_rate_per_100000  \
# 0                                     48.43
# 1                                     47.25
# 2                                     54.49
# 3                                     54.26
# 4                                     53.94
# ...                                     ...
# 3137                                  40.71
# 3138                                    NaN
# 3139                                    NaN
# 3140                                    NaN
# 3141                                  40.75
#
#       prostate_cancer_incidence_rate_per_100000  ...  median_household_income  \
# 0                                         133.2  ...                  58786.0
# 1                                          88.4  ...                  55962.0
# 2                                         146.2  ...                      NaN
# 3                                         112.7  ...                      NaN
# 4                                          96.9  ...                  48695.0
# ...                                         ...  ...                      ...
# 3137                                      136.1  ...                  73008.0
# 3138                                      125.5  ...                  83831.0
# 3139                                        NaN  ...                  58235.0
# 3140                                       86.4  ...                  53426.0
# 3141                                        NaN  ...                  52867.0
#
#       language_isolation_percent  over_65_percent  below_poverty_percent  \
# 0                            0.7             32.5                   12.0
# 1                            1.4             33.9                    NaN
# 2                            1.5              NaN                   21.5
# 3                            0.7             33.7                   10.5
# 4                            1.5             33.9                   10.2
# ...                          ...              ...                    ...
# 3137                         2.4              NaN                   10.0
# 3138                         5.0             34.6                    NaN
# 3139                         NaN              NaN                   11.0
# 3140                         1.3             33.9                    NaN
# 3141                         2.1             34.1                   12.6
#
#       uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 0                  20.0       4563.0                             1.1
# 1                  25.7       4492.0                             0.8
# 2                  18.5       4642.0                             NaN
# 3                  17.5       4499.0                             NaN
# 4                  25.2       4416.0                             NaN
# ...                 ...          ...                             ...
# 3137               23.6       4577.0                             1.1
# 3138               36.4       4224.0                             1.4
# 3139               21.2       4532.0                             NaN
# 3140               22.7       4341.0                             NaN
# 3141               23.0       4264.0                             4.4
#
#       black_percent  hispanic_percent  white_percent
# 0              19.1               NaN            NaN
# 1               9.5               4.5           86.3
# 2              47.6               4.3            NaN
# 3              22.3               NaN            NaN
# 4               1.5               9.1           95.5
# ...             ...               ...            ...
# 3137            NaN              16.0           93.1
# 3138            1.2              14.9           90.3
# 3139            NaN               9.1           93.4
# 3140            NaN              14.2           89.7
# 3141            NaN               NaN           92.5
#
# [3142 rows x 25 columns]

# %%
# Shannon County, SD (fips 46113) was renamed to Oglala Lakota County (fips 46102)
# Combine those two rows
county.loc[county["fips"] == 46113, "fips"] = 46102
county = county.groupby("fips").max().reset_index()

county[(county["fips"] == 46113) | (county["fips"] == 46102)]
# Out:
#        fips  cancer_incidence_rate_per_100000  \
# 2410  46102                             433.4
#
#       cancer_mortality_rate_per_100000  \
# 2410                            212.98
#
#       breast_cancer_incidence_rate_per_100000  \
# 2410                                      NaN
#
#       breast_cancer_mortality_rate_per_100000  \
# 2410                                      NaN
#
#       colorectal_cancer_incidence_rate_per_100000  \
# 2410                                         54.0
#
#       colorectal_cancer_mortality_rate_per_100000  \
# 2410                                          NaN
#
#       lung_cancer_incidence_rate_per_100000  \
# 2410                                   84.5
#
#       lung_cancer_mortality_rate_per_100000  \
# 2410                                  56.26
#
#       prostate_cancer_incidence_rate_per_100000  ...  median_household_income  \
# 2410                                       95.6  ...                      NaN
#
#       language_isolation_percent  over_65_percent  below_poverty_percent  \
# 2410                         1.6              NaN                   45.1
#
#       uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 2410               16.6       4299.0                             NaN
#
#       black_percent  hispanic_percent  white_percent
# 2410            NaN               3.9            NaN
#
# [1 rows x 25 columns]

# %%
# Wade Hampton Census Area, AK (fips 02270) was renamed to Kusilvak Census Area (fips 02158)
# Combine those two rows
county.loc[county["fips"] == 2270, "fips"] = 2158
county = county.groupby("fips").max().reset_index()

county[(county["fips"] == 2158) | (county["fips"] == 2158)]
# Out:
#     fips  cancer_incidence_rate_per_100000  cancer_mortality_rate_per_100000  \
# 80  2158                               NaN                            171.79
#
#     breast_cancer_incidence_rate_per_100000  \
# 80                                      NaN
#
#     breast_cancer_mortality_rate_per_100000  \
# 80                                      NaN
#
#     colorectal_cancer_incidence_rate_per_100000  \
# 80                                        102.1
#
#     colorectal_cancer_mortality_rate_per_100000  \
# 80                                          NaN
#
#     lung_cancer_incidence_rate_per_100000  \
# 80                                    NaN
#
#     lung_cancer_mortality_rate_per_100000  \
# 80                                    NaN
#
#     prostate_cancer_incidence_rate_per_100000  ...  median_household_income  \
# 80                                        NaN  ...                      NaN
#
#     language_isolation_percent  over_65_percent  below_poverty_percent  \
# 80                         3.7              NaN                   39.0
#
#     uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 80               15.6          NaN                             NaN
#
#     black_percent  hispanic_percent  white_percent
# 80            NaN               NaN            NaN
#
# [1 rows x 25 columns]

# %%
# Drop counties that aren't in our map
county = county[county["fips"] != 2201]
county = county[county["fips"] != 2232]

county[(county["fips"] == 2201) | (county["fips"] == 2232)]
# Out:
# Empty DataFrame
# Columns: [fips, cancer_incidence_rate_per_100000, cancer_mortality_rate_per_100000, breast_cancer_incidence_rate_per_100000, breast_cancer_mortality_rate_per_100000, colorectal_cancer_incidence_rate_per_100000, colorectal_cancer_mortality_rate_per_100000, lung_cancer_incidence_rate_per_100000, lung_cancer_mortality_rate_per_100000, prostate_cancer_incidence_rate_per_100000, prostate_cancer_mortality_rate_per_100000, leukemia_cancer_incidence_rate_per_100000, leukemia_cancer_mortality_rate_per_100000, non_hodgkin_lymphoma_cancer_incidence_rate_per_100000, non_hodgkin_lymphoma_cancer_mortality_rate_per_100000, median_household_income, language_isolation_percent, over_65_percent, below_poverty_percent, uninsured_percent, uv_exposure, asian_pacific_islander_percent, black_percent, hispanic_percent, white_percent]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Read population counts from the Social Vulnerability Index
svi = pd.read_csv("../../data/processed/social_vulnerability_index.csv")
svi = svi[["fips", "population", "population_over_65"]]
svi.head()
# Out:
#    fips  population  population_over_65
# 0  1001       55639                8490
# 1  1003      218289               44716
# 2  1005       25026                4777
# 3  1007       22374                3676
# 4  1009       57755               10382

# %%
# Shannon County, SD (fips 46113) was renamed to Oglala Lakota County (fips 46102)
svi.loc[svi["fips"] == 46113, "fips"] = 46102
svi = svi.groupby("fips").max().reset_index()
# Wade Hampton Census Area, AK (fips 02270) was renamed to Kusilvak Census Area (fips 02158)
svi.loc[svi["fips"] == 2270, "fips"] = 2158
svi = svi.groupby("fips").max().reset_index()

# %% [markdown]
# ## Pre-process data frames
# We need to join tables so both the state and county dataframes have the state fips code and population

# %%
# Join county with the population data
county = county.set_index("fips").join(svi.set_index("fips"), how="outer").reset_index()

# Add in the state FIPs code for cross-referencing
county["state_fips"] = (county["fips"]/1000).apply(np.floor).astype(int)

county.head()
# Out:
#    fips  cancer_incidence_rate_per_100000  cancer_mortality_rate_per_100000  \
# 0  1001                             490.1                            163.48
# 1  1003                             452.4                            165.47
# 2  1005                               NaN                            182.94
# 3  1007                             467.3                            187.60
# 4  1009                             432.0                            176.72
#
#    breast_cancer_incidence_rate_per_100000  \
# 0                                    129.9
# 1                                    128.1
# 2                                      NaN
# 3                                    140.7
# 4                                    130.0
#
#    breast_cancer_mortality_rate_per_100000  \
# 0                                    21.59
# 1                                    22.20
# 2                                      NaN
# 3                                    22.05
# 4                                    20.36
#
#    colorectal_cancer_incidence_rate_per_100000  \
# 0                                         49.5
# 1                                         40.4
# 2                                         44.1
# 3                                         47.0
# 4                                         36.7
#
#    colorectal_cancer_mortality_rate_per_100000  \
# 0                                        15.19
# 1                                        13.93
# 2                                        15.42
# 3                                        14.30
# 4                                        14.17
#
#    lung_cancer_incidence_rate_per_100000  \
# 0                                   67.8
# 1                                   70.0
# 2                                   63.1
# 3                                   78.3
# 4                                   70.3
#
#    lung_cancer_mortality_rate_per_100000  \
# 0                                  48.43
# 1                                  47.25
# 2                                  54.49
# 3                                  54.26
# 4                                  53.94
#
#    prostate_cancer_incidence_rate_per_100000  ...  below_poverty_percent  \
# 0                                      133.2  ...                   12.0
# 1                                       88.4  ...                    NaN
# 2                                      146.2  ...                   21.5
# 3                                      112.7  ...                   10.5
# 4                                       96.9  ...                   10.2
#
#    uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 0               20.0       4563.0                             1.1
# 1               25.7       4492.0                             0.8
# 2               18.5       4642.0                             NaN
# 3               17.5       4499.0                             NaN
# 4               25.2       4416.0                             NaN
#
#    black_percent  hispanic_percent  white_percent  population  \
# 0           19.1               NaN            NaN     55639.0
# 1            9.5               4.5           86.3    218289.0
# 2           47.6               4.3            NaN     25026.0
# 3           22.3               NaN            NaN     22374.0
# 4            1.5               9.1           95.5     57755.0
#
#    population_over_65  state_fips
# 0              8490.0           1
# 1             44716.0           1
# 2              4777.0           1
# 3              3676.0           1
# 4             10382.0           1
#
# [5 rows x 28 columns]

# %%
# Join state with the population data
svi["state_fips"] = (svi["fips"] / 1000).apply(np.floor).astype(int)
svi_state = (
    svi.groupby("state_fips")
    .agg({"population": "sum", "population_over_65": "sum"})
    .reset_index()
    .rename(columns={"state_fips": "fips"})
)

state = state.set_index("fips").join(svi_state.set_index("fips")).reset_index()
state = state.rename(columns={"fips": "state_fips"})

state.head()
# Out:
#    state_fips  cancer_incidence_rate_per_100000  \
# 0           1                             451.5
# 1           2                             417.2
# 2           4                             386.7
# 3           5                             472.8
# 4           6                             404.6
#
#    cancer_mortality_rate_per_100000  breast_cancer_incidence_rate_per_100000  \
# 0                            173.42                                    121.6
# 1                            152.62                                    120.8
# 2                            137.88                                    114.4
# 3                            177.63                                    118.2
# 4                            140.30                                    121.5
#
#    breast_cancer_mortality_rate_per_100000  \
# 0                                    21.54
# 1                                    18.80
# 2                                    18.47
# 3                                    20.33
# 4                                    19.35
#
#    cervical_cancer_incidence_rate_per_100000  \
# 0                                        9.4
# 1                                        7.1
# 2                                        6.5
# 3                                        9.5
# 4                                        7.2
#
#    cervical_cancer_mortality_rate_per_100000  \
# 0                                       3.46
# 1                                       1.65
# 2                                       2.10
# 3                                       3.43
# 4                                       2.24
#
#    colorectal_cancer_incidence_rate_per_100000  \
# 0                                         43.6
# 1                                         42.6
# 2                                         32.6
# 3                                         44.1
# 4                                         35.1
#
#    colorectal_cancer_mortality_rate_per_100000  \
# 0                                        15.46
# 1                                        15.05
# 2                                        12.62
# 3                                        15.59
# 4                                        12.50
#
#    lung_cancer_incidence_rate_per_100000  ...  \
# 0                                   64.9  ...
# 1                                   55.8  ...
# 2                                   46.8  ...
# 3                                   77.2  ...
# 4                                   41.5  ...
#
#    leukemia_cancer_mortality_rate_per_100000  \
# 0                                       6.40
# 1                                       5.55
# 2                                       5.85
# 3                                       6.79
# 4                                       5.86
#
#    non_hodgkin_lymphoma_cancer_incidence_rate_per_100000  \
# 0                                               16.2
# 1                                               17.1
# 2                                               15.5
# 3                                               18.2
# 4                                               18.4
#
#    non_hodgkin_lymphoma_cancer_mortality_rate_per_100000  \
# 0                                               5.02
# 1                                               5.50
# 2                                               4.67
# 3                                               5.30
# 4                                               5.17
#
#    hodgkins_lymphoma_cancer_mortality_rate_per_100000  \
# 0                                               0.31
# 1                                                NaN
# 2                                               0.28
# 3                                               0.30
# 4                                               0.31
#
#    hodgkins_lymphoma_cancer_incidence_rate_per_100000  \
# 0                                               2.42
# 1                                               2.13
# 2                                               2.00
# 3                                               2.62
# 4                                               2.18
#
#    colorectal_screening_percent  smoking_percent  hpv_vaccine_percent  \
# 0                         76.07            43.94                 34.9
# 1                         68.36            43.22                 32.3
# 2                         75.32            40.35                 39.9
# 3                         73.39            47.06                 26.8
# 4                         75.60            33.45                 38.8
#
#    population  population_over_65
# 0     4893186              827434
# 1      736990               87629
# 2     7174064             1262204
# 3     3011873              510117
# 4    39346023             5644497
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Extrapolate cancer rates
#
# Using the population data, subtract the known county data from the state data and use that rate for the remaining counties.

# %%
bounds = state.describe(percentiles=[0.005, 0.995])
bounds
# Out:
#        state_fips  cancer_incidence_rate_per_100000  \
# count   51.000000                         51.000000
# mean    28.960784                        451.100000
# std     15.832828                         30.404033
# min      1.000000                        374.900000
# 0.5%     1.250000                        377.850000
# 50%     29.000000                        457.100000
# 99.5%   55.750000                        511.750000
# max     56.000000                        519.600000
#
#        cancer_mortality_rate_per_100000  \
# count                         51.000000
# mean                         157.963725
# std                           14.446722
# min                          123.860000
# 0.5%                         125.422500
# 50%                          157.150000
# 99.5%                        190.020000
# max                          191.190000
#
#        breast_cancer_incidence_rate_per_100000  \
# count                                51.000000
# mean                                127.107843
# std                                   7.952882
# min                                 111.800000
# 0.5%                                111.975000
# 50%                                 127.400000
# 99.5%                               143.650000
# max                                 144.700000
#
#        breast_cancer_mortality_rate_per_100000  \
# count                                51.000000
# mean                                 20.088627
# std                                   1.859838
# min                                  16.070000
# 0.5%                                 16.375000
# 50%                                  19.840000
# 99.5%                                25.442500
# max                                  26.200000
#
#        cervical_cancer_incidence_rate_per_100000  \
# count                                  51.000000
# mean                                    7.370588
# std                                     1.321710
# min                                     4.300000
# 0.5%                                    4.400000
# 50%                                     7.300000
# 99.5%                                   9.575000
# max                                     9.600000
#
#        cervical_cancer_mortality_rate_per_100000  \
# count                                  51.000000
# mean                                    2.115098
# std                                     0.607557
# min                                     1.050000
# 0.5%                                    1.057500
# 50%                                     2.070000
# 99.5%                                   3.452500
# max                                     3.460000
#
#        colorectal_cancer_incidence_rate_per_100000  \
# count                                    51.000000
# mean                                     38.762745
# std                                       4.192754
# min                                      29.800000
# 0.5%                                     30.475000
# 50%                                      38.000000
# 99.5%                                    48.200000
# max                                      48.300000
#
#        colorectal_cancer_mortality_rate_per_100000  \
# count                                    51.000000
# mean                                     13.900000
# std                                       1.645586
# min                                      10.690000
# 0.5%                                     10.752500
# 50%                                      13.710000
# 99.5%                                    17.877500
# max                                      18.010000
#
#        lung_cancer_incidence_rate_per_100000  ...  \
# count                              51.000000  ...
# mean                               59.629412  ...
# std                                11.532758  ...
# min                                26.000000  ...
# 0.5%                               29.125000  ...
# 50%                                59.100000  ...
# 99.5%                              88.200000  ...
# max                                91.000000  ...
#
#        leukemia_cancer_mortality_rate_per_100000  \
# count                                  51.000000
# mean                                    6.320784
# std                                     0.585672
# min                                     4.610000
# 0.5%                                    4.652500
# 50%                                     6.350000
# 99.5%                                   7.485000
# max                                     7.520000
#
#        non_hodgkin_lymphoma_cancer_incidence_rate_per_100000  \
# count                                          51.000000
# mean                                           18.813725
# std                                             1.890505
# min                                            15.100000
# 0.5%                                           15.150000
# 50%                                            18.900000
# 99.5%                                          23.300000
# max                                            23.800000
#
#        non_hodgkin_lymphoma_cancer_mortality_rate_per_100000  \
# count                                          51.000000
# mean                                            5.421961
# std                                             0.447312
# min                                             4.470000
# 0.5%                                            4.472500
# 50%                                             5.360000
# 99.5%                                           6.107500
# max                                             6.110000
#
#        hodgkins_lymphoma_cancer_mortality_rate_per_100000  \
# count                                          44.000000
# mean                                            0.289773
# std                                             0.041399
# min                                             0.200000
# 0.5%                                            0.204300
# 50%                                             0.285000
# 99.5%                                           0.407100
# max                                             0.420000
#
#        hodgkins_lymphoma_cancer_incidence_rate_per_100000  \
# count                                          50.000000
# mean                                            2.589200
# std                                             0.336621
# min                                             1.730000
# 0.5%                                            1.796150
# 50%                                             2.545000
# 99.5%                                           3.242650
# max                                             3.250000
#
#        colorectal_screening_percent  smoking_percent  hpv_vaccine_percent  \
# count                     51.000000        51.000000            51.000000
# mean                      75.578235        41.571569            35.437255
# std                        3.760924         4.414515             7.048488
# min                       66.960000        24.950000            19.100000
# 0.5%                      67.062500        27.075000            20.450000
# 50%                       75.460000        42.270000            35.200000
# 99.5%                     81.572500        50.232500            53.200000
# max                       81.620000        50.400000            53.300000
#
#          population  population_over_65
# count  5.100000e+01        5.100000e+01
# mean   6.403320e+06        1.026722e+06
# std    7.314917e+06        1.116249e+06
# min    5.813480e+05        8.591200e+04
# 0.5%   5.920960e+05        8.634125e+04
# 50%    4.461952e+06        7.299280e+05
# 99.5%  3.666838e+07        5.320351e+06
# max    3.934602e+07        5.644497e+06
#
# [8 rows x 26 columns]

# %%
# Population to use when extrapolating cancer rates
population_metric = "population_over_65"

# Fills in the data for metric in the county data frame (c) using the state data frame (s)
def fill_data(s, c, metric):
    # Get the relevant columns
    df_county = c[["fips", "state_fips", population_metric, metric]]
    df_state = s[["state_fips", population_metric, metric]]

    # Find the total number of incidences in the counties with known rates
    df_county["county_total"] = (
        df_county[population_metric] * df_county[metric] / 100000
    )

    # Sum up the populations of all counties in each state that don't have data for the metric
    missing_counties = df_county[df_county[metric].isna()]
    df_state = (
        df_state.set_index("state_fips")
        .join(
            missing_counties.groupby("state_fips")
            .agg({population_metric: "sum"})
            .rename(
                columns={
                    population_metric: "missing_data_" + population_metric,
                }
            )
        )
        .reset_index()
    )

    # Calculate the total number of incidences in each state
    df_state["state_total"] = df_state[population_metric] * df_state[metric] / 100000

    # Find the number of cases attributed to counties
    county_total = df_county.groupby("state_fips").agg({"county_total": "sum"})

    # Join with the state data
    df_state = df_state.set_index("state_fips").join(county_total).reset_index()

    # Due to age adjustment, some states have slightly negative values. Those should
    # be reset to 0 when calculating the diff
    df_state["diff"] = np.maximum(df_state["state_total"] - df_state["county_total"], 0)

    # Calculate values for all counties with missing data.
    df_state[metric] = (
        df_state["diff"] / df_state["missing_data_" + population_metric] * 100000
    )

    # Go through all values of metric and fill in the missing ones
    lower_bound = bounds.loc["0.5%", metric]
    upper_bound = bounds.loc["99.5%", metric]
    for i in county.index:
        if np.isnan(county.iloc[i].loc[metric]):
            state_fips = county.iloc[i].loc["state_fips"].astype(int)
            val = df_state[df_state["state_fips"] == state_fips].iloc[0].loc[metric]
            county_sum = (
                df_state[df_state["state_fips"] == state_fips]
                .iloc[0]
                .loc["county_total"]
            )

            # Check if the value is within 99% confidence interval plus error for the metric
            error = (upper_bound - lower_bound) * 0.05
            if (
                val > lower_bound - error and val < upper_bound + error
            ) or county_sum == 0:
                county.iloc[i, county.columns.get_loc(metric)] = val

# %%
# Calculate population over 65 more completely
county["over_65_percent"] = county["population_over_65"] * 100 / county["population"]
county
# Out:
#        fips  cancer_incidence_rate_per_100000  \
# 0      1001                             490.1
# 1      1003                             452.4
# 2      1005                               NaN
# 3      1007                             467.3
# 4      1009                             432.0
# ...     ...                               ...
# 3142  56037                               NaN
# 3143  56039                               NaN
# 3144  56041                               NaN
# 3145  56043                               NaN
# 3146  56045                               NaN
#
#       cancer_mortality_rate_per_100000  \
# 0                               163.48
# 1                               165.47
# 2                               182.94
# 3                               187.60
# 4                               176.72
# ...                                ...
# 3142                               NaN
# 3143                               NaN
# 3144                               NaN
# 3145                               NaN
# 3146                               NaN
#
#       breast_cancer_incidence_rate_per_100000  \
# 0                                       129.9
# 1                                       128.1
# 2                                         NaN
# 3                                       140.7
# 4                                       130.0
# ...                                       ...
# 3142                                      NaN
# 3143                                    141.0
# 3144                                    139.5
# 3145                                    130.2
# 3146                                    129.2
#
#       breast_cancer_mortality_rate_per_100000  \
# 0                                       21.59
# 1                                       22.20
# 2                                         NaN
# 3                                       22.05
# 4                                       20.36
# ...                                       ...
# 3142                                    21.63
# 3143                                      NaN
# 3144                                    31.52
# 3145                                      NaN
# 3146                                      NaN
#
#       colorectal_cancer_incidence_rate_per_100000  \
# 0                                            49.5
# 1                                            40.4
# 2                                            44.1
# 3                                            47.0
# 4                                            36.7
# ...                                           ...
# 3142                                          NaN
# 3143                                          NaN
# 3144                                          NaN
# 3145                                         44.7
# 3146                                          NaN
#
#       colorectal_cancer_mortality_rate_per_100000  \
# 0                                           15.19
# 1                                           13.93
# 2                                           15.42
# 3                                           14.30
# 4                                           14.17
# ...                                           ...
# 3142                                        14.20
# 3143                                          NaN
# 3144                                          NaN
# 3145                                          NaN
# 3146                                          NaN
#
#       lung_cancer_incidence_rate_per_100000  \
# 0                                      67.8
# 1                                      70.0
# 2                                      63.1
# 3                                      78.3
# 4                                      70.3
# ...                                     ...
# 3142                                    NaN
# 3143                                    NaN
# 3144                                    NaN
# 3145                                    NaN
# 3146                                    NaN
#
#       lung_cancer_mortality_rate_per_100000  \
# 0                                     48.43
# 1                                     47.25
# 2                                     54.49
# 3                                     54.26
# 4                                     53.94
# ...                                     ...
# 3142                                  40.71
# 3143                                    NaN
# 3144                                    NaN
# 3145                                    NaN
# 3146                                  40.75
#
#       prostate_cancer_incidence_rate_per_100000  ...  below_poverty_percent  \
# 0                                         133.2  ...                   12.0
# 1                                          88.4  ...                    NaN
# 2                                         146.2  ...                   21.5
# 3                                         112.7  ...                   10.5
# 4                                          96.9  ...                   10.2
# ...                                         ...  ...                    ...
# 3142                                      136.1  ...                   10.0
# 3143                                      125.5  ...                    NaN
# 3144                                        NaN  ...                   11.0
# 3145                                       86.4  ...                    NaN
# 3146                                        NaN  ...                   12.6
#
#       uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 0                  20.0       4563.0                             1.1
# 1                  25.7       4492.0                             0.8
# 2                  18.5       4642.0                             NaN
# 3                  17.5       4499.0                             NaN
# 4                  25.2       4416.0                             NaN
# ...                 ...          ...                             ...
# 3142               23.6       4577.0                             1.1
# 3143               36.4       4224.0                             1.4
# 3144               21.2       4532.0                             NaN
# 3145               22.7       4341.0                             NaN
# 3146               23.0       4264.0                             4.4
#
#       black_percent  hispanic_percent  white_percent  population  \
# 0              19.1               NaN            NaN     55639.0
# 1               9.5               4.5           86.3    218289.0
# 2              47.6               4.3            NaN     25026.0
# 3              22.3               NaN            NaN     22374.0
# 4               1.5               9.1           95.5     57755.0
# ...             ...               ...            ...         ...
# 3142            NaN              16.0           93.1     43352.0
# 3143            1.2              14.9           90.3     23356.0
# 3144            NaN               9.1           93.4     20374.0
# 3145            NaN              14.2           89.7      7933.0
# 3146            NaN               NaN           92.5      6942.0
#
#       population_over_65  state_fips
# 0                 8490.0           1
# 1                44716.0           1
# 2                 4777.0           1
# 3                 3676.0           1
# 4                10382.0           1
# ...                  ...         ...
# 3142              5292.0          56
# 3143              3481.0          56
# 3144              2868.0          56
# 3145              1716.0          56
# 3146              1408.0          56
#
# [3147 rows x 28 columns]

# %%
# Iterate over all cancer metrics to fill in missing data
for m in list(filter(lambda x: "rate" in x, county.columns)):
    fill_data(state, county, m)

# Drop columns used to process data
county = county.drop(columns=["state_fips", "population", "population_over_65"])

county
# Out:
# <ipython-input-242-163c9f855364>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_county["county_total"] = (
#        fips  cancer_incidence_rate_per_100000  \
# 0      1001                        490.100000
# 1      1003                        452.400000
# 2      1005                        425.703515
# 3      1007                        467.300000
# 4      1009                        432.000000
# ...     ...                               ...
# 3142  56037                        384.839000
# 3143  56039                        384.839000
# 3144  56041                        384.839000
# 3145  56043                        384.839000
# 3146  56045                        384.839000
#
#       cancer_mortality_rate_per_100000  \
# 0                            163.48000
# 1                            165.47000
# 2                            182.94000
# 3                            187.60000
# 4                            176.72000
# ...                                ...
# 3142                         135.74306
# 3143                         135.74306
# 3144                         135.74306
# 3145                         135.74306
# 3146                         135.74306
#
#       breast_cancer_incidence_rate_per_100000  \
# 0                                       129.9
# 1                                       128.1
# 2                                         NaN
# 3                                       140.7
# 4                                       130.0
# ...                                       ...
# 3142                                      NaN
# 3143                                    141.0
# 3144                                    139.5
# 3145                                    130.2
# 3146                                    129.2
#
#       breast_cancer_mortality_rate_per_100000  \
# 0                                   21.590000
# 1                                   22.200000
# 2                                   18.871149
# 3                                   22.050000
# 4                                   20.360000
# ...                                       ...
# 3142                                21.630000
# 3143                                      NaN
# 3144                                31.520000
# 3145                                      NaN
# 3146                                      NaN
#
#       colorectal_cancer_incidence_rate_per_100000  \
# 0                                       49.500000
# 1                                       40.400000
# 2                                       44.100000
# 3                                       47.000000
# 4                                       36.700000
# ...                                           ...
# 3142                                    29.982216
# 3143                                    29.982216
# 3144                                    29.982216
# 3145                                    44.700000
# 3146                                    29.982216
#
#       colorectal_cancer_mortality_rate_per_100000  \
# 0                                           15.19
# 1                                           13.93
# 2                                           15.42
# 3                                           14.30
# 4                                           14.17
# ...                                           ...
# 3142                                        14.20
# 3143                                          NaN
# 3144                                          NaN
# 3145                                          NaN
# 3146                                          NaN
#
#       lung_cancer_incidence_rate_per_100000  \
# 0                                 67.800000
# 1                                 70.000000
# 2                                 63.100000
# 3                                 78.300000
# 4                                 70.300000
# ...                                     ...
# 3142                              41.686433
# 3143                              41.686433
# 3144                              41.686433
# 3145                              41.686433
# 3146                              41.686433
#
#       lung_cancer_mortality_rate_per_100000  \
# 0                                 48.430000
# 1                                 47.250000
# 2                                 54.490000
# 3                                 54.260000
# 4                                 53.940000
# ...                                     ...
# 3142                              40.710000
# 3143                              27.651654
# 3144                              27.651654
# 3145                              27.651654
# 3146                              40.750000
#
#       prostate_cancer_incidence_rate_per_100000  ...  median_household_income  \
# 0                                         133.2  ...                  58786.0
# 1                                          88.4  ...                  55962.0
# 2                                         146.2  ...                      NaN
# 3                                         112.7  ...                      NaN
# 4                                          96.9  ...                  48695.0
# ...                                         ...  ...                      ...
# 3142                                      136.1  ...                  73008.0
# 3143                                      125.5  ...                  83831.0
# 3144                                        NaN  ...                  58235.0
# 3145                                       86.4  ...                  53426.0
# 3146                                        NaN  ...                  52867.0
#
#       language_isolation_percent  over_65_percent  below_poverty_percent  \
# 0                            0.7        15.259081                   12.0
# 1                            1.4        20.484770                    NaN
# 2                            1.5        19.088148                   21.5
# 3                            0.7        16.429785                   10.5
# 4                            1.5        17.975933                   10.2
# ...                          ...              ...                    ...
# 3142                         2.4        12.207049                   10.0
# 3143                         5.0        14.904093                    NaN
# 3144                         NaN        14.076765                   11.0
# 3145                         1.3        21.631161                    NaN
# 3146                         2.1        20.282339                   12.6
#
#       uninsured_percent  uv_exposure  asian_pacific_islander_percent  \
# 0                  20.0       4563.0                             1.1
# 1                  25.7       4492.0                             0.8
# 2                  18.5       4642.0                             NaN
# 3                  17.5       4499.0                             NaN
# 4                  25.2       4416.0                             NaN
# ...                 ...          ...                             ...
# 3142               23.6       4577.0                             1.1
# 3143               36.4       4224.0                             1.4
# 3144               21.2       4532.0                             NaN
# 3145               22.7       4341.0                             NaN
# 3146               23.0       4264.0                             4.4
#
#       black_percent  hispanic_percent  white_percent
# 0              19.1               NaN            NaN
# 1               9.5               4.5           86.3
# 2              47.6               4.3            NaN
# 3              22.3               NaN            NaN
# 4               1.5               9.1           95.5
# ...             ...               ...            ...
# 3142            NaN              16.0           93.1
# 3143            1.2              14.9           90.3
# 3144            NaN               9.1           93.4
# 3145            NaN              14.2           89.7
# 3146            NaN               NaN           92.5
#
# [3147 rows x 25 columns]

# %%
# Write out the cleaned data
county.to_csv("../../data/processed/nci.csv", index=False)
